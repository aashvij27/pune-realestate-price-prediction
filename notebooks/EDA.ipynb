# %% [markdown]
# # Pune Real Estate EDA
#
# This notebook triggers the reusable EDA pipeline and previews the cleaned feature-engineered dataset.

# %%
from pathlib import Path
import sys
import pandas as pd

project_root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
df = pd.read_csv(project_root / 'data' / 'cleaned' / 'pune_feature_engineered.csv')
df.head()

# %%
from src.eda.eda_analysis import generate_eda_plots

generate_eda_plots(df)
print('Plots saved to notebooks/figures/')
